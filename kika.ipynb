# %%
# Open files to check the data

import pandas as pd

path = "/Users/mariamorazamora/Downloads/"

reviews = pd.read_csv(path + "reviews.csv")
calendar = pd.read_csv(path + "calendar.csv")
listings = pd.read_csv(path + "listings.csv")

# %%
# Check the data

reviews
# Out:
#                  listing_id                   id        date  reviewer_id  \
# 0                     48154               117554  2010-10-12       180238
# 1                     48154               145645  2010-11-28       204240
# 2                     48154               190572  2011-03-01       258565
# 3                     48154               195081  2011-03-08       213496
# 4                     48154               218435  2011-04-05       340330
# ...                     ...                  ...         ...          ...
# 405025  1504733249256762074  1514471314508913781  2025-09-20    525122895
# 405026  1510081689361956872  1516580931973236287  2025-09-23    189096452
# 405027  1510742831916234236  1516659592553285100  2025-09-23    284767483
# 405028  1511011655639848026  1513877915190428616  2025-09-19    115416651
# 405029  1511011655639848026  1514454866572706462  2025-09-20    719681112
#
#           reviewer_name                                           comments
# 0                Martha  Toni's place was perfect in so many ways.  It ...
# 1                  Mark  Awesome stay!! We'd recommend Toni's apartment...
# 2              Domenico  really nice house in a wonderfull position! yo...
# 3       Romina & Martín  Apartamento muy agradable, al igual que su pro...
# 4                 Jenna  Was a great apartment, easy access to the site...
# ...                 ...                                                ...
# 405025             Alex  Het appartement was geweldig, fijne lokatie in...
# 405026           Marcos                       todo muy bien, lo recomiendo
# 405027         Cem-Kaan  Das Penthouse war absolut exzellent – ein echt...
# 405028          Leticia  This place is next to the beach but  the neigh...
# 405029            Emily      Me encanta ti muy limpio y fácil de encontrar
#
# [405030 rows x 6 columns]

# %%
calendar
# Out:
#          listing_id        date available  price  adjusted_price  \
# 0           2053439  2025-09-24         f    NaN             NaN
# 1           2053439  2025-09-25         f    NaN             NaN
# 2           2053439  2025-09-26         t    NaN             NaN
# 3           2053439  2025-09-27         f    NaN             NaN
# 4           2053439  2025-09-28         f    NaN             NaN
# ...             ...         ...       ...    ...             ...
# 2863055     8770808  2026-09-19         f    NaN             NaN
# 2863056     8770808  2026-09-20         f    NaN             NaN
# 2863057     8770808  2026-09-21         f    NaN             NaN
# 2863058     8770808  2026-09-22         f    NaN             NaN
# 2863059     8770808  2026-09-23         f    NaN             NaN
#
#          minimum_nights  maximum_nights
# 0                     3              30
# 1                     3              30
# 2                     3              30
# 3                     3              30
# 4                     3              30
# ...                 ...             ...
# 2863055               3             365
# 2863056               3             365
# 2863057               3             365
# 2863058               3             365
# 2863059               3             365
#
# [2863060 rows x 7 columns]

# %%
listings
# Out:
#                        id                                       listing_url  \
# 0                   48154                https://www.airbnb.com/rooms/48154
# 1                  137143               https://www.airbnb.com/rooms/137143
# 2                  149715               https://www.airbnb.com/rooms/149715
# 3                  165971               https://www.airbnb.com/rooms/165971
# 4                  182221               https://www.airbnb.com/rooms/182221
# ...                   ...                                               ...
# 7839  1512890541606203698  https://www.airbnb.com/rooms/1512890541606203698
# 7840  1513129542493588113  https://www.airbnb.com/rooms/1513129542493588113
# 7841  1513797288967204559  https://www.airbnb.com/rooms/1513797288967204559
# 7842  1514333702066164803  https://www.airbnb.com/rooms/1514333702066164803
# 7843  1514336330133264750  https://www.airbnb.com/rooms/1514336330133264750
#
#            scrape_id last_scraped       source  \
# 0     20250923203019   2025-09-24  city scrape
# 1     20250923203019   2025-09-24  city scrape
# 2     20250923203019   2025-09-24  city scrape
# 3     20250923203019   2025-09-24  city scrape
# 4     20250923203019   2025-09-24  city scrape
# ...              ...          ...          ...
# 7839  20250923203019   2025-09-24  city scrape
# 7840  20250923203019   2025-09-24  city scrape
# 7841  20250923203019   2025-09-24  city scrape
# 7842  20250923203019   2025-09-24  city scrape
# 7843  20250923203019   2025-09-24  city scrape
#
#                                                    name  \
# 0                         Precioso apartamento con wifi
# 1                        PENTHOUSE  ON FRONT LINE BEACH
# 2             1900 Style Valencian Beach  Home for 10px
# 3                              ★ Architectural touch! ★
# 4                    Apartments Calatrava City Valencia
# ...                                                 ...
# 7839                               Apartamento familiar
# 7840  2 Habitación privada cerca del centro, wifi, m...
# 7841       1 Habitación Céntrica Metro Segura con Llave
# 7842                                       Habitación 2
# 7843         Suite Embajador No. 3 - Casa del Patriarca
#
#                                             description  \
# 0     Second floor on a farm from the late 19th cent...
# 1                                                   NaN
# 2     Typical town house with 5 bedrooms and 4 bathr...
# 3     Hola! I am ready to welcome you in my apt., wh...
# 4                                                   NaN
# ...                                                 ...
# 7839  This special place is close to everything, mak...
# 7840  Rest in a private and functional room, equippe...
# 7841  ⭐️ Rest in a private and functional room, equi...
# 7842  Enjoy the simplicity of this quiet and central...
# 7843  Suite at the Casa del Patriarca hotel, perfect...
#
#                                   neighborhood_overview  \
# 0     Very close neighborhood to the city's old town...
# 1                                                   NaN
# 2     Surrounded by  historic houses,  authentic res...
# 3     Just outside the old city centre (one block aw...
# 4                                                   NaN
# ...                                                 ...
# 7839                                                NaN
# 7840                                                NaN
# 7841                                                NaN
# 7842                                                NaN
# 7843                                                NaN
#
#                                             picture_url    host_id  ...  \
# 0     https://a0.muscache.com/pictures/1109085/9c0d4...     219476  ...
# 1     https://a0.muscache.com/pictures/hosting/Hosti...     670775  ...
# 2     https://a0.muscache.com/pictures/808b4883-c57f...       5947  ...
# 3     https://a0.muscache.com/pictures/10878830/ade6...     791187  ...
# 4     https://a0.muscache.com/pictures/1161513/9f7ac...    1315567  ...
# ...                                                 ...        ...  ...
# 7839  https://a0.muscache.com/pictures/hosting/Hosti...  719445669  ...
# 7840  https://a0.muscache.com/pictures/hosting/Hosti...  719672175  ...
# 7841  https://a0.muscache.com/pictures/hosting/Hosti...  719672175  ...
# 7842  https://a0.muscache.com/pictures/hosting/Hosti...  682595718  ...
# 7843  https://a0.muscache.com/pictures/hosting/Hosti...  284433465  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                           4.80                   4.52                4.52
# 1                           5.00                   4.00                4.00
# 2                           4.89                   4.63                4.62
# 3                           4.88                   4.84                4.84
# 4                           4.67                   4.33                4.44
# ...                          ...                    ...                 ...
# 7839                         NaN                    NaN                 NaN
# 7840                         NaN                    NaN                 NaN
# 7841                         NaN                    NaN                 NaN
# 7842                         NaN                    NaN                 NaN
# 7843                         NaN                    NaN                 NaN
#
#                                                 license instant_bookable  \
# 0                                            VT-41540-V                f
# 1                                              VT32745V                f
# 2     ESFCTU000046025000580569000000000000000000VT-3...                f
# 3                                            VT-32757-V                t
# 4                                            VT-38755-V                f
# ...                                                 ...              ...
# 7839                                        VT-082345-V                f
# 7840                                         BAP153962V                f
# 7841                                         BAP153962A                f
# 7842                                      VT 14304256 V                f
# 7843                                          CVH00133V                f
#
#      calculated_host_listings_count  \
# 0                                 4
# 1                                 5
# 2                                 1
# 3                                 8
# 4                                 1
# ...                             ...
# 7839                              1
# 7840                              2
# 7841                              2
# 7842                              3
# 7843                              1
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              4
# 1                                              5
# 2                                              1
# 3                                              8
# 4                                              1
# ...                                          ...
# 7839                                           1
# 7840                                           0
# 7841                                           0
# 7842                                           0
# 7843                                           0
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 7839                                            0
# 7840                                            2
# 7841                                            2
# 7842                                            3
# 7843                                            1
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0              1.08
# 1                                              0              0.01
# 2                                              0              1.81
# 3                                              0              3.34
# 4                                              0              0.07
# ...                                          ...               ...
# 7839                                           0               NaN
# 7840                                           0               NaN
# 7841                                           0               NaN
# 7842                                           0               NaN
# 7843                                           0               NaN
#
# [7844 rows x 79 columns]

# %%
# Check for NaN values

reviews.isna().sum()
# Out:
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     1
# comments         21
# dtype: int64

# %%
calendar.isna().sum()
# Out:
# listing_id              0
# date                    0
# available               0
# price             2863060
# adjusted_price    2863060
# minimum_nights          0
# maximum_nights          0
# dtype: int64

# %%
listings.isna().sum()
# Out:
# id                                                0
# listing_url                                       0
# scrape_id                                         0
# last_scraped                                      0
# source                                            0
#                                                ...
# calculated_host_listings_count                    0
# calculated_host_listings_count_entire_homes       0
# calculated_host_listings_count_private_rooms      0
# calculated_host_listings_count_shared_rooms       0
# reviews_per_month                               977
# Length: 79, dtype: int64
