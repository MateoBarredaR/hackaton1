# %%
import pandas as pd

df_listings = pd.read_csv("/Users/mateobarreda/Desktop/hackaton/listings 2.csv")
df_listings.head()

df_reviews = pd.read_csv("/Users/mateobarreda/Desktop/hackaton/reviews.csv")
df_reviews.info()

df_calendar = pd.read_csv("/Users/mateobarreda/Desktop/hackaton/calendar.csv")
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405030 entries, 0 to 405029
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     405030 non-null  int64
#  1   id             405030 non-null  int64
#  2   date           405030 non-null  object
#  3   reviewer_id    405030 non-null  int64
#  4   reviewer_name  405029 non-null  object
#  5   comments       405009 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 18.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2863060 entries, 0 to 2863059
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 152.9+ MB

# %%
#code to find a specific listing by its ID
listing_id = 48154
specific_listing = df_listings[df_listings['id'] == listing_id]
print(specific_listing)

specific_calendar = df_calendar[df_calendar['listing_id'] == listing_id]
print(specific_calendar)

specific_reviews = df_reviews[df_reviews['listing_id'] == listing_id]
print(specific_reviews)

#With this we checked how are the datasets united by the listing_id and id
#We realized that listings.cvs has the id as "id" and calendar.cvs. This way we will see the
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  48154  https://www.airbnb.com/rooms/48154  20250923203019   2025-09-24
#
#         source                           name  \
# 0  city scrape  Precioso apartamento con wifi
#
#                                          description  \
# 0  Second floor on a farm from the late 19th cent...
#
#                                neighborhood_overview  \
# 0  Very close neighborhood to the city's old town...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/1109085/9c0d4...   219476  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                         4.8                   4.52                4.52
#
#       license instant_bookable calculated_host_listings_count  \
# 0  VT-41540-V                f                              4
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           4
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.08
#
# [1 rows x 79 columns]
#          listing_id        date available  price  adjusted_price  \
# 2388560       48154  2025-09-24         f    NaN             NaN
# 2388561       48154  2025-09-25         f    NaN             NaN
# 2388562       48154  2025-09-26         f    NaN             NaN
# 2388563       48154  2025-09-27         f    NaN             NaN
# 2388564       48154  2025-09-28         t    NaN             NaN
# ...             ...         ...       ...    ...             ...
# 2388920       48154  2026-09-19         f    NaN             NaN
# 2388921       48154  2026-09-20         f    NaN             NaN
# 2388922       48154  2026-09-21         f    NaN             NaN
# 2388923       48154  2026-09-22         f    NaN             NaN
# 2388924       48154  2026-09-23         f    NaN             NaN
#
#          minimum_nights  maximum_nights
# 2388560               4              10
# 2388561               4              10
# 2388562               4              10
# 2388563               4              10
# 2388564               4              10
# ...                 ...             ...
# 2388920               3              25
# 2388921               3              25
# 2388922               3              25
# 2388923               3              25
# 2388924               3              25
#
# [365 rows x 7 columns]
#      listing_id                   id        date  reviewer_id  \
# 0         48154               117554  2010-10-12       180238
# 1         48154               145645  2010-11-28       204240
# 2         48154               190572  2011-03-01       258565
# 3         48154               195081  2011-03-08       213496
# 4         48154               218435  2011-04-05       340330
# ..          ...                  ...         ...          ...
# 192       48154  1478253976351035178  2025-08-01    704604530
# 193       48154  1481857321048423498  2025-08-06    170217988
# 194       48154  1487633990536901322  2025-08-14    468665288
# 195       48154  1489094887567185326  2025-08-16    711309479
# 196       48154  1510876121078612003  2025-09-15    596874767
#
#        reviewer_name                                           comments
# 0             Martha  Toni's place was perfect in so many ways.  It ...
# 1               Mark  Awesome stay!! We'd recommend Toni's apartment...
# 2           Domenico  really nice house in a wonderfull position! yo...
# 3    Romina & Martín  Apartamento muy agradable, al igual que su pro...
# 4              Jenna  Was a great apartment, easy access to the site...
# ..               ...                                                ...
# 192           Franck  Logement assez spacieux (la deuxième chambre e...
# 193           Javier  Cerca del centro. Muy bien sin pretensiones se...
# 194       Alessandro  host molto gentile,  ci ha consigliato svariat...
# 195      Eva Rosibel  muy cómodo ,acogedor ,limpio y lo que nos gust...
# 196          Cameron  Lovely little apartment, exactly as shown in p...
#
# [197 rows x 6 columns]

# %%
#We start our analysis with the listings dataset
df_listings.describe()
df_listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')
